# %%
import pickle
with open('/kaggle/input/pre-processamentoe/x_orig_mod_gaussianfilter.pkl', 'rb') as f:
    X = pickle.load(f)
    
with open('/kaggle/input/pre-processamentoe/y_orig_mod.pkl', 'rb') as f:
    Y = pickle.load(f)

# %%
import numpy as np
#Y = Y.astype(np.float32)

# %%
'''import cv2
import numpy as np
from tensorflow.image import resize

# Supondo que X seja uma lista de imagens coloridas.
X_resized = np.array([resize(image, [100, 100]) for image in X])
#imagens_cinza = np.array([cv2.cvtColor(image.astype('uint8'), cv2.COLOR_BGR2GRAY) for image in X_resized])

def converter_para_rgb(imagens_cinza):
    imagens_rgb = np.stack((imagens_cinza,) * 3, axis=-1)
    return imagens_rgb

imagens_rgba = converter_para_rgb(imagens_cinza)



imagens_rgba[0].shape
#X = preprocess_input(imagens_rgba)

X = X_resized
X.shape


# Convertendo a lista em um array NumPy
X = np.array(X)'''
# Out:
# "import cv2\nimport numpy as np\nfrom tensorflow.image import resize\n\n# Supondo que X seja uma lista de imagens coloridas.\nX_resized = np.array([resize(image, [100, 100]) for image in X])\n#imagens_cinza = np.array([cv2.cvtColor(image.astype('uint8'), cv2.COLOR_BGR2GRAY) for image in X_resized])\n\ndef converter_para_rgb(imagens_cinza):\n    imagens_rgb = np.stack((imagens_cinza,) * 3, axis=-1)\n    return imagens_rgb\n\nimagens_rgba = converter_para_rgb(imagens_cinza)\n\n\n\nimagens_rgba[0].shape\n#X = preprocess_input(imagens_rgba)\n\nX = X_resized\nX.shape\n\n\n# Convertendo a lista em um array NumPy\nX = np.array(X)"

# %%
print(np.min(X))
print(np.max(X))
X.shape
# Out:
# 0
# 255
# (9947, 100, 100, 3)

# %%
from keras.applications.resnet50 import preprocess_input 
X = preprocess_input(X)
# Out:
# 2024-07-29 17:01:23.312358: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-29 17:01:23.312466: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-29 17:01:23.445714: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
print(np.min(X))
print(np.max(X))
X.shape
# Out:
# -123.68
# 151.061
# (9947, 100, 100, 3)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=1)

# %%
import numpy as np

unique, counts = np.unique(Y_train, return_counts=True)
ocorrencias = dict(zip(unique, counts))
print("Distribuição no conjunto de treino")
print(ocorrencias)

unique, counts = np.unique(Y_test, return_counts=True)
ocorrencias = dict(zip(unique, counts))

print("Distribuição no conjunto de teste")
print(ocorrencias)
# Out:
# Distribuição no conjunto de treino
# {0: 6304, 1: 1653}
# Distribuição no conjunto de teste
# {0: 1562, 1: 428}

# %%
'''import os
import cv2
import albumentations as A
from skimage.io import imread, imsave
from pathlib import Path

# transformações
import albumentations as A

transformacoes = A.Compose([
    A.ShiftScaleRotate(shift_limit=0.2, scale_limit=0.2, rotate_limit=40, p=1),
    A.HorizontalFlip(p=0.5),
])



novas = 10

index = 0
labels = []
x_train = []

for arquivo in X_train:
    imagem = arquivo
    holder = Y_train[index]
    index += 1
    for i in range(novas):
        imagem_transformada = transformacoes(image=imagem)['image']
        labels.append(holder)
        x_train.append(imagem_transformada)
        
import numpy as np


X_train = np.array(x_train)  
Y_train = np.array(labels)  
'''
import numpy as np
import albumentations as A

# Transformações
transformacoes = A.Compose([
    A.Rotate(limit=20),
    A.ShiftScaleRotate(shift_limit=0.2, scale_limit=0.2, rotate_limit=0),
    A.HorizontalFlip(),
    A.RandomScale(scale_limit=0.1),
    A.Resize(width=100, height=100, p=1),  # Garante que todas as imagens tenham o mesmo tamanho
])

novas = 4
labels = []
x_train = []

for index, imagem in enumerate(X_train):
    holder = Y_train[index]
    
    # Redimensionar a imagem original para garantir uniformidade
    imagem_resized = transformacoes(image=imagem)['image']
    
    if Y_train[index] == 0:
        labels.append(holder)
        x_train.append(imagem_resized)
    else:
        for i in range(novas):
            imagem_transformada = transformacoes(image=imagem)['image']
            labels.append(holder)
            x_train.append(imagem_transformada)

# Convertendo as listas para arrays NumPy
X_train = np.stack(x_train)  # Usa np.stack para garantir que as imagens sejam empilhadas corretamente
Y_train = np.array(labels)  # Convertendo para NumPy array

# %%
import numpy as np

unique, counts = np.unique(Y_train, return_counts=True)
ocorrencias = dict(zip(unique, counts))
print("Distribuição no conjunto de treino")
print(ocorrencias)

unique, counts = np.unique(Y_test, return_counts=True)
ocorrencias = dict(zip(unique, counts))

print("Distribuição no conjunto de teste")
print(ocorrencias)
# Out:
# Distribuição no conjunto de treino
# {0: 6304, 1: 6612}
# Distribuição no conjunto de teste
# {0: 1562, 1: 428}

# %%
# Criando o objeto StratifiedKFold para 3 folds
from sklearn.model_selection import StratifiedKFold
kfold = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)

# Dicionário para armazenar os dados de treino de cada fold
folds = {}

# Dividindo os dados em folds
for i, (train_index, _) in enumerate(kfold.split(X_train, Y_train)):
    folds[f'x_train_{i+1}'] = X_train[train_index]
    folds[f'y_train_{i+1}'] = Y_train[train_index]

# Agora você tem x_train_1, y_train_1, x_train_2, y_train_2, x_train_3, y_train_3 armazenados no dicionário `folds`
x_train_1, y_train_1 = folds['x_train_1'], folds['y_train_1']
x_train_2, y_train_2 = folds['x_train_2'], folds['y_train_2']
x_train_3, y_train_3 = folds['x_train_3'], folds['y_train_3']

# %%
import numpy as np

unique, counts = np.unique(y_train_1, return_counts=True)
ocorrencias = dict(zip(unique, counts))
print("Distribuição no FOLD 1")
print(ocorrencias)

unique, counts = np.unique(y_train_2, return_counts=True)
ocorrencias = dict(zip(unique, counts))

print("Distribuição no FOLD 2")
print(ocorrencias)

unique, counts = np.unique(y_train_3, return_counts=True)
ocorrencias = dict(zip(unique, counts))

print("Distribuição no FOLD 3")
print(ocorrencias)
# Out:
# Distribuição no FOLD 1
# {0: 4202, 1: 4408}
# Distribuição no FOLD 2
# {0: 4203, 1: 4408}
# Distribuição no FOLD 3
# {0: 4203, 1: 4408}

# %%
from sklearn.model_selection import StratifiedKFold
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import classification_report, roc_auc_score
import numpy as np
import time
import tensorflow as tf
from tensorflow.keras.regularizers import l2
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.applications.resnet50 import ResNet50

def create_resnet50():
        base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(100, 100, 3))
        x = base_model.output
        x = GlobalAveragePooling2D()(x)
        x = Dense(512, activation='relu', kernel_regularizer=l2(0.01))(x)
        x = BatchNormalization()(x)
        x = Dropout(0.25)(x)
        x = Dense(256, activation='relu', kernel_regularizer=l2(0.01))(x)
        x = BatchNormalization()(x)
        x = Dropout(0.25)(x)
        x = Dense(128, activation='relu', kernel_regularizer=l2(0.01))(x)
        x = BatchNormalization()(x)
        x = Dropout(0.3)(x)
        predictions = Dense(1, activation='sigmoid', kernel_regularizer=l2(0.01))(x)
        model = Model(inputs=base_model.input, outputs=predictions)

        for layer in base_model.layers:
            layer.trainable = False
        model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])
        return model

# %%
from sklearn.model_selection import StratifiedKFold
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import classification_report, roc_auc_score
import numpy as np
import time
import tensorflow as tf
from tensorflow.keras.regularizers import l2

scores = []
tempo = []
historys = []
metricas_por_fold = []
melhor_model = None
melhor_f1_score = 0

if(True):
    start_time = time.time()
    tf.keras.backend.clear_session()
    
    n_splits = 3
    hist = []
    holder = []
    metricas_fold = []
    
    kfold = StratifiedKFold(n_splits=n_splits, shuffle=True)
    
    i = 0
    for train_idx, val_idx in kfold.split(X_train, Y_train):
        tf.keras.backend.clear_session()
        early_stopping = EarlyStopping(monitor='val_acc', patience=10, verbose=1, mode='min', restore_best_weights=True)
        reduce_lr = ReduceLROnPlateau(monitor='val_acc', factor=0.2, patience=5, verbose=1, mode='min', min_lr=1e-5)
        modelo = create_resnet50()
        X_train_fold, Y_train_fold = X_train[train_idx], Y_train[train_idx]
        X_val_fold, Y_val_fold = X_train[val_idx], Y_train[val_idx]
        
        history = modelo.fit(X_train_fold, Y_train_fold, epochs=30, validation_data=(X_val_fold, Y_val_fold), callbacks=[early_stopping, reduce_lr])
        holder.append(modelo.evaluate(X_val_fold, Y_val_fold, verbose=0))

        # Previsão e cálculo das métricas para o conjunto de validação
        previsoes_val = modelo.predict(X_val_fold)
        previsoes_binarias_val = [1 if x > 0.5 else 0 for x in previsoes_val]

        # Relatório de Classificação para o conjunto de validação
        relatorio_dict = classification_report(Y_val_fold, previsoes_binarias_val, target_names=["Classe 0", "Classe 1"], output_dict=True)
        precision_val = relatorio_dict['macro avg']['precision']
        recall_val = relatorio_dict['macro avg']['recall']
        f1_val = relatorio_dict['macro avg']['f1-score']
        
        # Calcular AUC-ROC
        auc_roc_val = roc_auc_score(Y_val_fold, previsoes_val)
        
        print("Relatório de Classificação (Validação):\n", classification_report(Y_val_fold, previsoes_binarias_val, target_names=["Classe 0", "Classe 1"]))
        print(f"F1: {f1_val:.4f}, Recall: {recall_val:.4f}, Precision: {precision_val:.4f}, AUC-ROC: {auc_roc_val:.4f}")
        metricas_fold.append((f1_val, recall_val, precision_val, auc_roc_val))
        
        # Verificar se este é o melhor modelo com base no F1-score
        if f1_val > melhor_f1_score:
            melhor_f1_score = f1_val
            melhor_model = modelo 
            bf = i
        i += 1
        del modelo

    # Guardar histórico e métricas
    hist.append(history)
    historys.append(hist)
    metricas_por_fold.append(metricas_fold)
    
    end_time = time.time()
    tempo.append(end_time - start_time)
    scores.append(holder)

# Exibir as métricas por fold e por fase
print(metricas_por_fold)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/30
#   7/270 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.6043 - loss: 13.8196
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1722272529.143387     103 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 43s 93ms/step - accuracy: 0.7410 - loss: 8.6379 - val_accuracy: 0.7933 - val_loss: 2.3501 - learning_rate: 0.0010
# Epoch 2/30
#   7/270 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.8252 - loss: 2.3080
# /opt/conda/lib/python3.10/site-packages/keras/src/callbacks/early_stopping.py:155: UserWarning: Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: accuracy,loss,val_accuracy,val_loss
#   current = self.get_monitor_value(logs)
# /opt/conda/lib/python3.10/site-packages/keras/src/callbacks/callback_list.py:96: UserWarning: Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: accuracy,loss,val_accuracy,val_loss,learning_rate.
#   callback.on_epoch_end(epoch, logs)
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 26ms/step - accuracy: 0.7819 - loss: 1.9701 - val_accuracy: 0.7838 - val_loss: 1.0914 - learning_rate: 0.0010
# Epoch 3/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.7903 - loss: 1.0272 - val_accuracy: 0.7870 - val_loss: 0.8364 - learning_rate: 0.0010
# Epoch 4/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.8004 - loss: 0.7952 - val_accuracy: 0.7873 - val_loss: 0.7022 - learning_rate: 0.0010
# Epoch 5/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 26ms/step - accuracy: 0.7824 - loss: 0.8658 - val_accuracy: 0.7847 - val_loss: 0.7521 - learning_rate: 0.0010
# Epoch 6/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.7980 - loss: 0.7396 - val_accuracy: 0.7970 - val_loss: 0.6729 - learning_rate: 0.0010
# Epoch 7/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 26ms/step - accuracy: 0.8087 - loss: 0.6528 - val_accuracy: 0.8084 - val_loss: 0.5997 - learning_rate: 0.0010
# Epoch 8/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.7955 - loss: 0.6615 - val_accuracy: 0.8007 - val_loss: 0.6077 - learning_rate: 0.0010
# Epoch 9/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.7910 - loss: 0.6493 - val_accuracy: 0.7778 - val_loss: 0.6485 - learning_rate: 0.0010
# Epoch 10/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 26ms/step - accuracy: 0.7901 - loss: 0.6738 - val_accuracy: 0.7724 - val_loss: 0.6629 - learning_rate: 0.0010
# Epoch 11/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.7945 - loss: 0.6201 - val_accuracy: 0.7845 - val_loss: 0.6118 - learning_rate: 0.0010
# Epoch 12/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 26ms/step - accuracy: 0.8017 - loss: 0.6094 - val_accuracy: 0.8045 - val_loss: 0.5646 - learning_rate: 0.0010
# Epoch 13/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.7996 - loss: 0.5835 - val_accuracy: 0.7840 - val_loss: 0.6040 - learning_rate: 0.0010
# Epoch 14/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.8000 - loss: 0.5888 - val_accuracy: 0.8063 - val_loss: 0.5652 - learning_rate: 0.0010
# Epoch 15/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 26ms/step - accuracy: 0.8032 - loss: 0.5658 - val_accuracy: 0.8119 - val_loss: 0.5554 - learning_rate: 0.0010
# Epoch 16/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 26ms/step - accuracy: 0.7928 - loss: 0.5686 - val_accuracy: 0.7889 - val_loss: 0.5942 - learning_rate: 0.0010
# Epoch 17/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.8011 - loss: 0.5769 - val_accuracy: 0.8033 - val_loss: 0.5545 - learning_rate: 0.0010
# Epoch 18/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.7994 - loss: 0.5553 - val_accuracy: 0.7761 - val_loss: 0.5826 - learning_rate: 0.0010
# Epoch 19/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.7990 - loss: 0.5574 - val_accuracy: 0.8163 - val_loss: 0.5326 - learning_rate: 0.0010
# Epoch 20/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.8112 - loss: 0.5398 - val_accuracy: 0.7898 - val_loss: 0.5690 - learning_rate: 0.0010
# Epoch 21/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 26ms/step - accuracy: 0.7993 - loss: 0.5448 - val_accuracy: 0.7353 - val_loss: 0.6652 - learning_rate: 0.0010
# Epoch 22/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.8089 - loss: 0.5393 - val_accuracy: 0.7724 - val_loss: 0.5879 - learning_rate: 0.0010
# Epoch 23/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 26ms/step - accuracy: 0.8121 - loss: 0.5265 - val_accuracy: 0.7764 - val_loss: 0.5820 - learning_rate: 0.0010
# Epoch 24/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 26ms/step - accuracy: 0.8114 - loss: 0.5295 - val_accuracy: 0.7924 - val_loss: 0.5523 - learning_rate: 0.0010
# Epoch 25/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 26ms/step - accuracy: 0.8090 - loss: 0.5589 - val_accuracy: 0.7905 - val_loss: 0.5455 - learning_rate: 0.0010
# Epoch 26/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.8090 - loss: 0.5094 - val_accuracy: 0.7970 - val_loss: 0.5316 - learning_rate: 0.0010
# Epoch 27/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 26ms/step - accuracy: 0.8203 - loss: 0.5443 - val_accuracy: 0.8021 - val_loss: 0.5607 - learning_rate: 0.0010
# Epoch 28/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.8046 - loss: 0.5407 - val_accuracy: 0.7455 - val_loss: 0.6938 - learning_rate: 0.0010
# Epoch 29/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.8052 - loss: 0.5591 - val_accuracy: 0.7445 - val_loss: 0.6796 - learning_rate: 0.0010
# Epoch 30/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.8169 - loss: 0.5325 - val_accuracy: 0.7480 - val_loss: 0.6847 - learning_rate: 0.0010
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 9s 41ms/step
# Relatório de Classificação (Validação):
#                precision    recall  f1-score   support
#
#     Classe 0       0.93      0.52      0.67      2102
#     Classe 1       0.68      0.96      0.80      2204
#
#     accuracy                           0.75      4306
#    macro avg       0.81      0.74      0.73      4306
# weighted avg       0.80      0.75      0.73      4306
#
# F1: 0.7327, Recall: 0.7428, Precision: 0.8060, AUC-ROC: 0.8632
# Epoch 1/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 41s 93ms/step - accuracy: 0.7301 - loss: 8.5542 - val_accuracy: 0.7902 - val_loss: 2.3607 - learning_rate: 0.0010
# Epoch 2/30
#   7/270 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.7872 - loss: 2.3709
# /opt/conda/lib/python3.10/site-packages/keras/src/callbacks/early_stopping.py:155: UserWarning: Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: accuracy,loss,val_accuracy,val_loss
#   current = self.get_monitor_value(logs)
# /opt/conda/lib/python3.10/site-packages/keras/src/callbacks/callback_list.py:96: UserWarning: Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: accuracy,loss,val_accuracy,val_loss,learning_rate.
#   callback.on_epoch_end(epoch, logs)
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 8s 28ms/step - accuracy: 0.7805 - loss: 1.9713 - val_accuracy: 0.7761 - val_loss: 1.0624 - learning_rate: 0.0010
# Epoch 3/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - accuracy: 0.7914 - loss: 1.0416 - val_accuracy: 0.7742 - val_loss: 0.7617 - learning_rate: 0.0010
# Epoch 4/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - accuracy: 0.8028 - loss: 0.7656 - val_accuracy: 0.7607 - val_loss: 0.6925 - learning_rate: 0.0010
# Epoch 5/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.7991 - loss: 0.6596 - val_accuracy: 0.7738 - val_loss: 0.6442 - learning_rate: 0.0010
# Epoch 6/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.7907 - loss: 0.6372 - val_accuracy: 0.7863 - val_loss: 0.6023 - learning_rate: 0.0010
# Epoch 7/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.7933 - loss: 0.6379 - val_accuracy: 0.7735 - val_loss: 0.6377 - learning_rate: 0.0010
# Epoch 8/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.7977 - loss: 0.5962 - val_accuracy: 0.7740 - val_loss: 0.6242 - learning_rate: 0.0010
# Epoch 9/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.7924 - loss: 0.6306 - val_accuracy: 0.7833 - val_loss: 0.6119 - learning_rate: 0.0010
# Epoch 10/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.7967 - loss: 0.5803 - val_accuracy: 0.7233 - val_loss: 0.7054 - learning_rate: 0.0010
# Epoch 11/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.7896 - loss: 0.6055 - val_accuracy: 0.7531 - val_loss: 0.6116 - learning_rate: 0.0010
# Epoch 12/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.7944 - loss: 0.5805 - val_accuracy: 0.7807 - val_loss: 0.5705 - learning_rate: 0.0010
# Epoch 13/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.8005 - loss: 0.5628 - val_accuracy: 0.8021 - val_loss: 0.5666 - learning_rate: 0.0010
# Epoch 14/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.8082 - loss: 0.5563 - val_accuracy: 0.7703 - val_loss: 0.5813 - learning_rate: 0.0010
# Epoch 15/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 8s 28ms/step - accuracy: 0.8051 - loss: 0.5547 - val_accuracy: 0.8005 - val_loss: 0.5680 - learning_rate: 0.0010
# Epoch 16/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - accuracy: 0.7976 - loss: 0.5707 - val_accuracy: 0.7580 - val_loss: 0.6071 - learning_rate: 0.0010
# Epoch 17/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - accuracy: 0.8146 - loss: 0.5492 - val_accuracy: 0.7661 - val_loss: 0.6275 - learning_rate: 0.0010
# Epoch 18/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 8s 28ms/step - accuracy: 0.8115 - loss: 0.5300 - val_accuracy: 0.7823 - val_loss: 0.5500 - learning_rate: 0.0010
# Epoch 19/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 8s 28ms/step - accuracy: 0.7835 - loss: 0.7091 - val_accuracy: 0.7902 - val_loss: 0.6008 - learning_rate: 0.0010
# Epoch 20/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - accuracy: 0.8053 - loss: 0.5907 - val_accuracy: 0.7677 - val_loss: 0.5864 - learning_rate: 0.0010
# Epoch 21/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.8062 - loss: 0.5767 - val_accuracy: 0.8037 - val_loss: 0.5543 - learning_rate: 0.0010
# Epoch 22/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.8208 - loss: 0.5367 - val_accuracy: 0.7963 - val_loss: 0.5584 - learning_rate: 0.0010
# Epoch 23/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 8s 28ms/step - accuracy: 0.8257 - loss: 0.5290 - val_accuracy: 0.8116 - val_loss: 0.5232 - learning_rate: 0.0010
# Epoch 24/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - accuracy: 0.8200 - loss: 0.5199 - val_accuracy: 0.8139 - val_loss: 0.5131 - learning_rate: 0.0010
# Epoch 25/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.8178 - loss: 0.5154 - val_accuracy: 0.8033 - val_loss: 0.5248 - learning_rate: 0.0010
# Epoch 26/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - accuracy: 0.8197 - loss: 0.5117 - val_accuracy: 0.6952 - val_loss: 0.6312 - learning_rate: 0.0010
# Epoch 27/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 8s 28ms/step - accuracy: 0.8184 - loss: 0.5176 - val_accuracy: 0.8072 - val_loss: 0.5185 - learning_rate: 0.0010
# Epoch 28/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - accuracy: 0.8288 - loss: 0.4993 - val_accuracy: 0.8002 - val_loss: 0.5329 - learning_rate: 0.0010
# Epoch 29/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - accuracy: 0.8171 - loss: 0.5436 - val_accuracy: 0.8158 - val_loss: 0.5086 - learning_rate: 0.0010
# Epoch 30/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - accuracy: 0.8174 - loss: 0.5051 - val_accuracy: 0.8072 - val_loss: 0.5077 - learning_rate: 0.0010
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step
# Relatório de Classificação (Validação):
#                precision    recall  f1-score   support
#
#     Classe 0       0.79      0.83      0.81      2101
#     Classe 1       0.83      0.78      0.81      2204
#
#     accuracy                           0.81      4305
#    macro avg       0.81      0.81      0.81      4305
# weighted avg       0.81      0.81      0.81      4305
#
# F1: 0.8072, Recall: 0.8078, Precision: 0.8080, AUC-ROC: 0.8949
# Epoch 1/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 38s 82ms/step - accuracy: 0.7359 - loss: 8.6974 - val_accuracy: 0.8000 - val_loss: 2.3531 - learning_rate: 0.0010
# Epoch 2/30
#   7/270 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - accuracy: 0.8603 - loss: 2.2402
# /opt/conda/lib/python3.10/site-packages/keras/src/callbacks/early_stopping.py:155: UserWarning: Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: accuracy,loss,val_accuracy,val_loss
#   current = self.get_monitor_value(logs)
# /opt/conda/lib/python3.10/site-packages/keras/src/callbacks/callback_list.py:96: UserWarning: Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: accuracy,loss,val_accuracy,val_loss,learning_rate.
#   callback.on_epoch_end(epoch, logs)
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 8s 28ms/step - accuracy: 0.7841 - loss: 1.9723 - val_accuracy: 0.7928 - val_loss: 1.0605 - learning_rate: 0.0010
# Epoch 3/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 8s 28ms/step - accuracy: 0.7908 - loss: 0.9520 - val_accuracy: 0.7826 - val_loss: 0.7076 - learning_rate: 0.0010
# Epoch 4/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 8s 28ms/step - accuracy: 0.7798 - loss: 0.7945 - val_accuracy: 0.7287 - val_loss: 0.7415 - learning_rate: 0.0010
# Epoch 5/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - accuracy: 0.7893 - loss: 0.7097 - val_accuracy: 0.8005 - val_loss: 0.6182 - learning_rate: 0.0010
# Epoch 6/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - accuracy: 0.7897 - loss: 0.6443 - val_accuracy: 0.7749 - val_loss: 0.6361 - learning_rate: 0.0010
# Epoch 7/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 8s 28ms/step - accuracy: 0.7869 - loss: 0.6152 - val_accuracy: 0.7800 - val_loss: 0.6486 - learning_rate: 0.0010
# Epoch 8/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 8s 28ms/step - accuracy: 0.7927 - loss: 0.6197 - val_accuracy: 0.7981 - val_loss: 0.5940 - learning_rate: 0.0010
# Epoch 9/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 8s 28ms/step - accuracy: 0.7815 - loss: 0.6799 - val_accuracy: 0.7596 - val_loss: 0.6973 - learning_rate: 0.0010
# Epoch 10/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - accuracy: 0.7959 - loss: 0.5961 - val_accuracy: 0.7250 - val_loss: 0.6790 - learning_rate: 0.0010
# Epoch 11/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 8s 28ms/step - accuracy: 0.7827 - loss: 0.8235 - val_accuracy: 0.7826 - val_loss: 0.6596 - learning_rate: 0.0010
# Epoch 12/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - accuracy: 0.7934 - loss: 0.6710 - val_accuracy: 0.8058 - val_loss: 0.5871 - learning_rate: 0.0010
# Epoch 13/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - accuracy: 0.8022 - loss: 0.5989 - val_accuracy: 0.7833 - val_loss: 0.6159 - learning_rate: 0.0010
# Epoch 14/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - accuracy: 0.8005 - loss: 0.6078 - val_accuracy: 0.8046 - val_loss: 0.5725 - learning_rate: 0.0010
# Epoch 15/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 8s 28ms/step - accuracy: 0.8082 - loss: 0.5668 - val_accuracy: 0.8009 - val_loss: 0.6074 - learning_rate: 0.0010
# Epoch 16/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.7932 - loss: 0.5986 - val_accuracy: 0.7865 - val_loss: 0.5499 - learning_rate: 0.0010
# Epoch 17/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - accuracy: 0.8034 - loss: 0.5453 - val_accuracy: 0.7470 - val_loss: 0.6928 - learning_rate: 0.0010
# Epoch 18/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - accuracy: 0.8102 - loss: 0.5468 - val_accuracy: 0.7370 - val_loss: 0.6141 - learning_rate: 0.0010
# Epoch 19/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - accuracy: 0.8054 - loss: 0.5579 - val_accuracy: 0.8056 - val_loss: 0.5289 - learning_rate: 0.0010
# Epoch 20/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - accuracy: 0.8063 - loss: 0.5350 - val_accuracy: 0.7849 - val_loss: 0.5931 - learning_rate: 0.0010
# Epoch 21/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 10s 27ms/step - accuracy: 0.7993 - loss: 0.5745 - val_accuracy: 0.7445 - val_loss: 0.6552 - learning_rate: 0.0010
# Epoch 22/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.8144 - loss: 0.5387 - val_accuracy: 0.7981 - val_loss: 0.5512 - learning_rate: 0.0010
# Epoch 23/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - accuracy: 0.8107 - loss: 0.5309 - val_accuracy: 0.8065 - val_loss: 0.5273 - learning_rate: 0.0010
# Epoch 24/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.8096 - loss: 0.5246 - val_accuracy: 0.8170 - val_loss: 0.5116 - learning_rate: 0.0010
# Epoch 25/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - accuracy: 0.8104 - loss: 0.5166 - val_accuracy: 0.8149 - val_loss: 0.5175 - learning_rate: 0.0010
# Epoch 26/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - accuracy: 0.8166 - loss: 0.5095 - val_accuracy: 0.7526 - val_loss: 0.6515 - learning_rate: 0.0010
# Epoch 27/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - accuracy: 0.8142 - loss: 0.5115 - val_accuracy: 0.8114 - val_loss: 0.5016 - learning_rate: 0.0010
# Epoch 28/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - accuracy: 0.8224 - loss: 0.4913 - val_accuracy: 0.8139 - val_loss: 0.5078 - learning_rate: 0.0010
# Epoch 29/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.8220 - loss: 0.4937 - val_accuracy: 0.8193 - val_loss: 0.5128 - learning_rate: 0.0010
# Epoch 30/30
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - accuracy: 0.8175 - loss: 0.5210 - val_accuracy: 0.8156 - val_loss: 0.4925 - learning_rate: 0.0010
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 9s 40ms/step
# Relatório de Classificação (Validação):
#                precision    recall  f1-score   support
#
#     Classe 0       0.89      0.71      0.79      2101
#     Classe 1       0.77      0.92      0.84      2204
#
#     accuracy                           0.82      4305
#    macro avg       0.83      0.81      0.81      4305
# weighted avg       0.83      0.82      0.81      4305
#
# F1: 0.8126, Recall: 0.8130, Precision: 0.8296, AUC-ROC: 0.9021
# [[(0.732702278633821, 0.7427711228265881, 0.8060433321387784, 0.8631733713117402), (0.8071944270574777, 0.807802286699532, 0.8080151419672887, 0.8948854188352102), (0.8126481529714784, 0.8130442594529785, 0.8296347553840255, 0.9021368486702814)]]

# %%
model = melhor_model

# %%
Y_test = np.array(Y_test)

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Certifique-se de que X_test e Y_test tenham a forma correta
print(f"Forma de X_test: {X_test.shape}")
print(f"Forma de Y_test: {Y_test.shape}")

# Verifique se X_test não está vazio
if X_test.size == 0:
    raise ValueError("X_test está vazio")

# Realize a predição
previsoes = model.predict(X_test)

# Verifique a forma das previsões
print(f"Forma das previsões: {previsoes.shape}")

# Converta as previsões para binário
previsoes_binarias = [1 if x > 0.5 else 0 for x in previsoes]

# Avaliação da acurácia
acuracia = accuracy_score(Y_test, previsoes_binarias)
print(f"Acurácia no conjunto de teste: {acuracia}")

# Matriz de Confusão
matriz_confusao = confusion_matrix(Y_test, previsoes_binarias)
print("Matriz de Confusão:\n", matriz_confusao)

# Plot da Matriz de Confusão
plt.figure(figsize=(10, 7))
sns.heatmap(matriz_confusao, annot=True, fmt="d", cmap="Blues", xticklabels=["Classe Negativa", "Classe Positiva"], yticklabels=["Classe Negativa", "Classe Positiva"])
plt.title('Matriz de Confusão')
plt.ylabel('Valor Real')
plt.xlabel('Valor Previsto')
plt.show()

# Relatório de Classificação
relatorio_classificacao = classification_report(Y_test, previsoes_binarias, target_names=["Classe 0", "Classe 1"])
print("Relatório de Classificação:\n", relatorio_classificacao)
# Out:
# Forma de X_test: (1990, 100, 100, 3)
# Forma de Y_test: (1990,)
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step
# Forma das previsões: (1990, 1)
# Acurácia no conjunto de teste: 0.7773869346733668
# Matriz de Confusão:
#  [[1176  386]
#  [  57  371]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#     Classe 0       0.95      0.75      0.84      1562
#     Classe 1       0.49      0.87      0.63       428
#
#     accuracy                           0.78      1990
#    macro avg       0.72      0.81      0.73      1990
# weighted avg       0.85      0.78      0.80      1990

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

def train_model(model, X_train, Y_train, EPOCHS=30):
    # Usando 'val_accuracy' em vez de 'val_acc'
    early_stop = EarlyStopping(monitor='val_accuracy', patience=10,verbose=1,
                               mode='max', restore_best_weights=True)

    reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.1, patience=5,
                                  verbose=1, mode='max', min_lr=1e-5)

    history = model.fit(X_train,
                        Y_train,
                        validation_split=0.2,
                        batch_size=16,
                        epochs=EPOCHS,
                        callbacks=[reduce_lr, early_stop])
    return history

# %%
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.applications.resnet50 import ResNet50

def create_resnet50_L():
    base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(100, 100, 3))
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(512, activation='relu', kernel_regularizer=l2(0.01))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.25)(x)
    x = Dense(256, activation='relu', kernel_regularizer=l2(0.01))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.25)(x)
    x = Dense(128, activation='relu', kernel_regularizer=l2(0.01))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.3)(x)
    predictions = Dense(1, activation='sigmoid', kernel_regularizer=l2(0.01))(x)
    model = Model(inputs=base_model.input, outputs=predictions)

    # Define o número de camadas a congelar
    # Neste caso, congelar as primeiras 165 camadas e treinar o restante
    for layer in base_model.layers[:165]:
        layer.trainable = False
    for layer in base_model.layers[165:]:
        layer.trainable = True

    model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np  # Importe a biblioteca NumPy

# Listas para armazenar as métricas de cada iteração
accuracies = []
precisions = []
recalls = []
f1_scores = []
historys = []
if(bf==0):
    treinox = x_train_1
    treinoy = y_train_1
    print("melor fold = 1")
elif(bf==1):
    treinox = x_train_2
    treinoy = y_train_2
    print("melor fold = 2")
else:
    treinox = x_train_3
    treinoy = y_train_3
    print("melor fold = 3")

for i in range(10):
    print("OIBOMDIA",i)
    tf.keras.backend.clear_session()
    model = create_resnet50_L()
    historys.append(train_model(model, treinox, treinoy, 30))

    previsoes = model.predict(X_test)
    previsoes_binarias = [1 if x > 0.5 else 0 for x in previsoes]

    # Adiciona a acurácia à lista
    acuracia = accuracy_score(Y_test, previsoes_binarias)
    accuracies.append(acuracia)

    # Calcula e adiciona precisão, recall e f1-score à suas respectivas listas
    relatorio_classificacao = classification_report(Y_test, previsoes_binarias, target_names=["Classe 0", "Classe 1"], output_dict=True)
    # Capturando os valores individuais de precisão, recall e F1-score para a classe '1'
    precisao_classe_1 = relatorio_classificacao['macro avg']['precision']
    recall_classe_1 = relatorio_classificacao['macro avg']['recall']
    f1_score_classe_1 = relatorio_classificacao['macro avg']['f1-score']

    print(f"Precisão : {precisao_classe_1}")
    print(f"Recall : {recall_classe_1}")
    print(f"F1-Score : {f1_score_classe_1}")

    precisions.append(precisao_classe_1)
    recalls.append(recall_classe_1)
    f1_scores.append(f1_score_classe_1)


# Calcula a média de cada métrica
acuracia_media = np.mean(accuracies)
precisao_media = np.mean(precisions)
recall_medio = np.mean(recalls)
f1_score_medio = np.mean(f1_scores)

# Calcula o desvio padrão de cada métrica
acuracia_dp = np.std(accuracies)
precisao_dp = np.std(precisions)
recall_dp = np.std(recalls)
f1_score_dp = np.std(f1_scores)

# Exibe os resultados
print(f"Acurácia média: {acuracia_media} ± {acuracia_dp}")
print(f"Precisão média: {precisao_media} ± {precisao_dp}")
print(f"Recall médio: {recall_medio} ± {recall_dp}")
print(f"F1-Score médio: {f1_score_medio} ± {f1_score_dp}")

# Opção para plotar a matriz de confusão da última iteração
cm = confusion_matrix(Y_test, previsoes_binarias)
sns.heatmap(cm, annot=True, fmt="d")
plt.xlabel('Predito')
plt.ylabel('Verdadeiro')
plt.show()

import matplotlib.pyplot as plt

# Configuração do gráfico de Acurácia
plt.figure(figsize=(14, 5))

# Gráfico de Acurácia por Época para cada history
plt.subplot(1, 2, 1)  # 1 linha, 2 colunas, posição 1
for history in historys:
    plt.plot(history.history['accuracy'], label='Acurácia (treino)')
    plt.plot(history.history['val_accuracy'], label='Acurácia (validação)')
plt.title('Acurácia por Época')
plt.xlabel('Época')
plt.ylabel('Acurácia')
plt.legend()

# Configuração do gráfico de Loss
plt.subplot(1, 2, 2)  # 1 linha, 2 colunas, posição 2
for history in historys:
    plt.plot(history.history['loss'], label='Loss (treino)')
    plt.plot(history.history['val_loss'], label='Loss (validação)')
plt.title('Loss por Época')
plt.xlabel('Época')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# melor fold = 3
# OIBOMDIA 0
# Epoch 1/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 49s 65ms/step - accuracy: 0.7122 - loss: 8.9121 - val_accuracy: 0.7690 - val_loss: 2.0458 - learning_rate: 0.0010
# Epoch 2/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7993 - loss: 1.5159 - val_accuracy: 0.7945 - val_loss: 0.7420 - learning_rate: 0.0010
# Epoch 3/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8353 - loss: 0.6066 - val_accuracy: 0.7092 - val_loss: 0.6484 - learning_rate: 0.0010
# Epoch 4/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8460 - loss: 0.4432 - val_accuracy: 0.8189 - val_loss: 0.5011 - learning_rate: 0.0010
# Epoch 5/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8733 - loss: 0.3761 - val_accuracy: 0.8195 - val_loss: 0.4976 - learning_rate: 0.0010
# Epoch 6/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9080 - loss: 0.3058 - val_accuracy: 0.8212 - val_loss: 0.5057 - learning_rate: 0.0010
# Epoch 7/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9047 - loss: 0.3290 - val_accuracy: 0.8067 - val_loss: 0.6886 - learning_rate: 0.0010
# Epoch 8/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9267 - loss: 0.2883 - val_accuracy: 0.8114 - val_loss: 0.5579 - learning_rate: 0.0010
# Epoch 9/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9228 - loss: 0.2813 - val_accuracy: 0.7858 - val_loss: 0.6982 - learning_rate: 0.0010
# Epoch 10/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9351 - loss: 0.2690 - val_accuracy: 0.8166 - val_loss: 0.6333 - learning_rate: 0.0010
# Epoch 11/30
# 428/431 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9434 - loss: 0.2539
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9434 - loss: 0.2538 - val_accuracy: 0.8085 - val_loss: 0.6670 - learning_rate: 0.0010
# Epoch 12/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9685 - loss: 0.1593 - val_accuracy: 0.8166 - val_loss: 0.4876 - learning_rate: 1.0000e-04
# Epoch 13/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9794 - loss: 0.0947 - val_accuracy: 0.8143 - val_loss: 0.4848 - learning_rate: 1.0000e-04
# Epoch 14/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9847 - loss: 0.0788 - val_accuracy: 0.8062 - val_loss: 0.6874 - learning_rate: 1.0000e-04
# Epoch 15/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9921 - loss: 0.0632 - val_accuracy: 0.8189 - val_loss: 0.7123 - learning_rate: 1.0000e-04
# Epoch 16/30
# 430/431 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9923 - loss: 0.0535
# Epoch 16: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9923 - loss: 0.0535 - val_accuracy: 0.8183 - val_loss: 0.7123 - learning_rate: 1.0000e-04
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 6.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 68ms/step
# Precisão : 0.7564659874593282
# Recall : 0.8235233405530891
# F1-Score : 0.7774136577708006
# OIBOMDIA 1
# Epoch 1/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 41s 54ms/step - accuracy: 0.7103 - loss: 8.7550 - val_accuracy: 0.7591 - val_loss: 1.9265 - learning_rate: 0.0010
# Epoch 2/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7980 - loss: 1.4362 - val_accuracy: 0.7824 - val_loss: 0.7110 - learning_rate: 0.0010
# Epoch 3/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8305 - loss: 0.5852 - val_accuracy: 0.8143 - val_loss: 0.5096 - learning_rate: 0.0010
# Epoch 4/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8420 - loss: 0.4456 - val_accuracy: 0.7858 - val_loss: 0.5608 - learning_rate: 0.0010
# Epoch 5/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8669 - loss: 0.3890 - val_accuracy: 0.7940 - val_loss: 0.5527 - learning_rate: 0.0010
# Epoch 6/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8915 - loss: 0.3418 - val_accuracy: 0.7905 - val_loss: 0.6836 - learning_rate: 0.0010
# Epoch 7/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8993 - loss: 0.3218 - val_accuracy: 0.8172 - val_loss: 0.5544 - learning_rate: 0.0010
# Epoch 8/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9248 - loss: 0.2780 - val_accuracy: 0.7974 - val_loss: 0.5850 - learning_rate: 0.0010
# Epoch 9/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9311 - loss: 0.2687 - val_accuracy: 0.8062 - val_loss: 0.6492 - learning_rate: 0.0010
# Epoch 10/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.9469 - loss: 0.2369 - val_accuracy: 0.7980 - val_loss: 0.6866 - learning_rate: 0.0010
# Epoch 11/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.9404 - loss: 0.2566 - val_accuracy: 0.7858 - val_loss: 0.7126 - learning_rate: 0.0010
# Epoch 12/30
# 428/431 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9518 - loss: 0.2508
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.9518 - loss: 0.2507 - val_accuracy: 0.7951 - val_loss: 0.7831 - learning_rate: 0.0010
# Epoch 13/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.9689 - loss: 0.1964 - val_accuracy: 0.8265 - val_loss: 0.5055 - learning_rate: 1.0000e-04
# Epoch 14/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.9853 - loss: 0.1074 - val_accuracy: 0.8294 - val_loss: 0.5603 - learning_rate: 1.0000e-04
# Epoch 15/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.9910 - loss: 0.0698 - val_accuracy: 0.8299 - val_loss: 0.7450 - learning_rate: 1.0000e-04
# Epoch 16/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.9898 - loss: 0.0723 - val_accuracy: 0.8212 - val_loss: 0.7888 - learning_rate: 1.0000e-04
# Epoch 17/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9930 - loss: 0.0634 - val_accuracy: 0.8253 - val_loss: 0.6816 - learning_rate: 1.0000e-04
# Epoch 18/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.9949 - loss: 0.0440 - val_accuracy: 0.8230 - val_loss: 0.6488 - learning_rate: 1.0000e-04
# Epoch 19/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.9881 - loss: 0.0628 - val_accuracy: 0.8317 - val_loss: 0.6740 - learning_rate: 1.0000e-04
# Epoch 20/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.9954 - loss: 0.0462 - val_accuracy: 0.8270 - val_loss: 0.6978 - learning_rate: 1.0000e-04
# Epoch 21/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.9947 - loss: 0.0476 - val_accuracy: 0.8334 - val_loss: 0.7156 - learning_rate: 1.0000e-04
# Epoch 22/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9975 - loss: 0.0386 - val_accuracy: 0.8224 - val_loss: 0.5505 - learning_rate: 1.0000e-04
# Epoch 23/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9973 - loss: 0.0407 - val_accuracy: 0.8270 - val_loss: 0.7795 - learning_rate: 1.0000e-04
# Epoch 24/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9988 - loss: 0.0278 - val_accuracy: 0.8288 - val_loss: 0.6692 - learning_rate: 1.0000e-04
# Epoch 25/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9985 - loss: 0.0315 - val_accuracy: 0.8236 - val_loss: 0.8551 - learning_rate: 1.0000e-04
# Epoch 26/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9968 - loss: 0.0384
# Epoch 26: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9968 - loss: 0.0384 - val_accuracy: 0.8265 - val_loss: 0.5711 - learning_rate: 1.0000e-04
# Epoch 27/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9985 - loss: 0.0388 - val_accuracy: 0.8288 - val_loss: 0.6776 - learning_rate: 1.0000e-05
# Epoch 28/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9987 - loss: 0.0347 - val_accuracy: 0.8276 - val_loss: 0.6771 - learning_rate: 1.0000e-05
# Epoch 29/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9984 - loss: 0.0334 - val_accuracy: 0.8323 - val_loss: 0.6680 - learning_rate: 1.0000e-05
# Epoch 30/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.9993 - loss: 0.0300 - val_accuracy: 0.8346 - val_loss: 0.6709 - learning_rate: 1.0000e-05
# Restoring model weights from the end of the best epoch: 30.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 72ms/step
# Precisão : 0.8009156120754561
# Recall : 0.8491315351753683
# F1-Score : 0.820164183222958
# OIBOMDIA 2
# Epoch 1/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 44s 58ms/step - accuracy: 0.7050 - loss: 8.6132 - val_accuracy: 0.8096 - val_loss: 1.8364 - learning_rate: 0.0010
# Epoch 2/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.8034 - loss: 1.4167 - val_accuracy: 0.8027 - val_loss: 0.7063 - learning_rate: 0.0010
# Epoch 3/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - accuracy: 0.8318 - loss: 0.5855 - val_accuracy: 0.8178 - val_loss: 0.5011 - learning_rate: 0.0010
# Epoch 4/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.8633 - loss: 0.4163 - val_accuracy: 0.7986 - val_loss: 0.5867 - learning_rate: 0.0010
# Epoch 5/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.8808 - loss: 0.3610 - val_accuracy: 0.8009 - val_loss: 0.6026 - learning_rate: 0.0010
# Epoch 6/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.9022 - loss: 0.3165 - val_accuracy: 0.8154 - val_loss: 0.5204 - learning_rate: 0.0010
# Epoch 7/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - accuracy: 0.9166 - loss: 0.3075 - val_accuracy: 0.8299 - val_loss: 0.5296 - learning_rate: 0.0010
# Epoch 8/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - accuracy: 0.9164 - loss: 0.2979 - val_accuracy: 0.8021 - val_loss: 0.5459 - learning_rate: 0.0010
# Epoch 9/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - accuracy: 0.9294 - loss: 0.2776 - val_accuracy: 0.7963 - val_loss: 0.6412 - learning_rate: 0.0010
# Epoch 10/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - accuracy: 0.9342 - loss: 0.2690 - val_accuracy: 0.8003 - val_loss: 0.6248 - learning_rate: 0.0010
# Epoch 11/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.9517 - loss: 0.2312 - val_accuracy: 0.8062 - val_loss: 0.5655 - learning_rate: 0.0010
# Epoch 12/30
# 428/431 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9515 - loss: 0.2262
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.9515 - loss: 0.2263 - val_accuracy: 0.8091 - val_loss: 0.7875 - learning_rate: 0.0010
# Epoch 13/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.9749 - loss: 0.1581 - val_accuracy: 0.8387 - val_loss: 0.4884 - learning_rate: 1.0000e-04
# Epoch 14/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.9853 - loss: 0.0913 - val_accuracy: 0.8334 - val_loss: 0.5202 - learning_rate: 1.0000e-04
# Epoch 15/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.9883 - loss: 0.0741 - val_accuracy: 0.8352 - val_loss: 0.5464 - learning_rate: 1.0000e-04
# Epoch 16/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.9918 - loss: 0.0628 - val_accuracy: 0.8439 - val_loss: 0.6843 - learning_rate: 1.0000e-04
# Epoch 17/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.9943 - loss: 0.0563 - val_accuracy: 0.8346 - val_loss: 0.7041 - learning_rate: 1.0000e-04
# Epoch 18/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.9965 - loss: 0.0422 - val_accuracy: 0.8352 - val_loss: 0.7102 - learning_rate: 1.0000e-04
# Epoch 19/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.9942 - loss: 0.0466 - val_accuracy: 0.8369 - val_loss: 0.7770 - learning_rate: 1.0000e-04
# Epoch 20/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.9928 - loss: 0.0528 - val_accuracy: 0.8288 - val_loss: 0.7433 - learning_rate: 1.0000e-04
# Epoch 21/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9954 - loss: 0.0469
# Epoch 21: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.9954 - loss: 0.0469 - val_accuracy: 0.8317 - val_loss: 0.7845 - learning_rate: 1.0000e-04
# Epoch 22/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.9969 - loss: 0.0352 - val_accuracy: 0.8369 - val_loss: 0.6752 - learning_rate: 1.0000e-05
# Epoch 23/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.9986 - loss: 0.0328 - val_accuracy: 0.8311 - val_loss: 0.6999 - learning_rate: 1.0000e-05
# Epoch 24/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.9992 - loss: 0.0293 - val_accuracy: 0.8305 - val_loss: 0.6790 - learning_rate: 1.0000e-05
# Epoch 25/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.9995 - loss: 0.0259 - val_accuracy: 0.8328 - val_loss: 0.7218 - learning_rate: 1.0000e-05
# Epoch 26/30
# 428/431 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9999 - loss: 0.0242
# Epoch 26: ReduceLROnPlateau reducing learning rate to 1e-05.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.9999 - loss: 0.0242 - val_accuracy: 0.8358 - val_loss: 0.6754 - learning_rate: 1.0000e-05
# Epoch 26: early stopping
# Restoring model weights from the end of the best epoch: 16.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 69ms/step
# Precisão : 0.7944469988636662
# Recall : 0.8515472614788133
# F1-Score : 0.8158453598637323
# OIBOMDIA 3
# Epoch 1/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 43s 56ms/step - accuracy: 0.7165 - loss: 8.7317 - val_accuracy: 0.7493 - val_loss: 1.8926 - learning_rate: 0.0010
# Epoch 2/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.7840 - loss: 1.4567 - val_accuracy: 0.8021 - val_loss: 0.7251 - learning_rate: 0.0010
# Epoch 3/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.8179 - loss: 0.6125 - val_accuracy: 0.8044 - val_loss: 0.5166 - learning_rate: 0.0010
# Epoch 4/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.8456 - loss: 0.4375 - val_accuracy: 0.8114 - val_loss: 0.5083 - learning_rate: 0.0010
# Epoch 5/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.8743 - loss: 0.3802 - val_accuracy: 0.7980 - val_loss: 0.5153 - learning_rate: 0.0010
# Epoch 6/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.8785 - loss: 0.3543 - val_accuracy: 0.8021 - val_loss: 0.5576 - learning_rate: 0.0010
# Epoch 7/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.9016 - loss: 0.3173 - val_accuracy: 0.8102 - val_loss: 0.5290 - learning_rate: 0.0010
# Epoch 8/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.9291 - loss: 0.2803 - val_accuracy: 0.7957 - val_loss: 0.5495 - learning_rate: 0.0010
# Epoch 9/30
# 429/431 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9299 - loss: 0.2804
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.9299 - loss: 0.2805 - val_accuracy: 0.7980 - val_loss: 0.7165 - learning_rate: 0.0010
# Epoch 10/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.9476 - loss: 0.2104 - val_accuracy: 0.8346 - val_loss: 0.4775 - learning_rate: 1.0000e-04
# Epoch 11/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.9709 - loss: 0.1316 - val_accuracy: 0.8317 - val_loss: 0.5461 - learning_rate: 1.0000e-04
# Epoch 12/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9821 - loss: 0.0932 - val_accuracy: 0.8346 - val_loss: 0.5702 - learning_rate: 1.0000e-04
# Epoch 13/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9870 - loss: 0.0767 - val_accuracy: 0.8299 - val_loss: 0.6694 - learning_rate: 1.0000e-04
# Epoch 14/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9881 - loss: 0.0719 - val_accuracy: 0.8334 - val_loss: 0.5731 - learning_rate: 1.0000e-04
# Epoch 15/30
# 430/431 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9878 - loss: 0.0751
# Epoch 15: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9878 - loss: 0.0751 - val_accuracy: 0.8270 - val_loss: 0.7146 - learning_rate: 1.0000e-04
# Epoch 16/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9907 - loss: 0.0633 - val_accuracy: 0.8305 - val_loss: 0.6360 - learning_rate: 1.0000e-05
# Epoch 17/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9928 - loss: 0.0582 - val_accuracy: 0.8334 - val_loss: 0.6335 - learning_rate: 1.0000e-05
# Epoch 18/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9962 - loss: 0.0468 - val_accuracy: 0.8328 - val_loss: 0.6594 - learning_rate: 1.0000e-05
# Epoch 19/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9957 - loss: 0.0428 - val_accuracy: 0.8282 - val_loss: 0.6772 - learning_rate: 1.0000e-05
# Epoch 20/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9956 - loss: 0.0467
# Epoch 20: ReduceLROnPlateau reducing learning rate to 1e-05.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9956 - loss: 0.0467 - val_accuracy: 0.8346 - val_loss: 0.6501 - learning_rate: 1.0000e-05
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 10.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 70ms/step
# Precisão : 0.7818856185690357
# Recall : 0.8506497780224251
# F1-Score : 0.8048681441129131
# OIBOMDIA 4
# Epoch 1/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 42s 55ms/step - accuracy: 0.7061 - loss: 8.9279 - val_accuracy: 0.7667 - val_loss: 2.0842 - learning_rate: 0.0010
# Epoch 2/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7982 - loss: 1.5662 - val_accuracy: 0.7951 - val_loss: 0.7670 - learning_rate: 0.0010
# Epoch 3/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8297 - loss: 0.6219 - val_accuracy: 0.7655 - val_loss: 0.5583 - learning_rate: 0.0010
# Epoch 4/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.8596 - loss: 0.4247 - val_accuracy: 0.8172 - val_loss: 0.4782 - learning_rate: 0.0010
# Epoch 5/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.8756 - loss: 0.3634 - val_accuracy: 0.7998 - val_loss: 0.5475 - learning_rate: 0.0010
# Epoch 6/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8999 - loss: 0.3357 - val_accuracy: 0.8125 - val_loss: 0.5023 - learning_rate: 0.0010
# Epoch 7/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9077 - loss: 0.3051 - val_accuracy: 0.7673 - val_loss: 0.6985 - learning_rate: 0.0010
# Epoch 8/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9179 - loss: 0.2931 - val_accuracy: 0.7980 - val_loss: 0.6878 - learning_rate: 0.0010
# Epoch 9/30
# 428/431 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9342 - loss: 0.2629
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9341 - loss: 0.2631 - val_accuracy: 0.8085 - val_loss: 0.7152 - learning_rate: 0.0010
# Epoch 10/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9548 - loss: 0.2238 - val_accuracy: 0.8253 - val_loss: 0.5196 - learning_rate: 1.0000e-04
# Epoch 11/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9729 - loss: 0.1383 - val_accuracy: 0.8299 - val_loss: 0.5004 - learning_rate: 1.0000e-04
# Epoch 12/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9811 - loss: 0.1015 - val_accuracy: 0.8241 - val_loss: 0.5415 - learning_rate: 1.0000e-04
# Epoch 13/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9864 - loss: 0.0886 - val_accuracy: 0.8358 - val_loss: 0.5899 - learning_rate: 1.0000e-04
# Epoch 14/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9881 - loss: 0.0745 - val_accuracy: 0.8299 - val_loss: 0.6485 - learning_rate: 1.0000e-04
# Epoch 15/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9902 - loss: 0.0642 - val_accuracy: 0.8288 - val_loss: 0.7112 - learning_rate: 1.0000e-04
# Epoch 16/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9886 - loss: 0.0691 - val_accuracy: 0.8375 - val_loss: 0.7180 - learning_rate: 1.0000e-04
# Epoch 17/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9950 - loss: 0.0548 - val_accuracy: 0.8241 - val_loss: 0.6402 - learning_rate: 1.0000e-04
# Epoch 18/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9925 - loss: 0.0536 - val_accuracy: 0.8241 - val_loss: 0.7229 - learning_rate: 1.0000e-04
# Epoch 19/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.9915 - loss: 0.0590 - val_accuracy: 0.8230 - val_loss: 0.6674 - learning_rate: 1.0000e-04
# Epoch 20/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.9939 - loss: 0.0591 - val_accuracy: 0.8224 - val_loss: 0.8270 - learning_rate: 1.0000e-04
# Epoch 21/30
# 428/431 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9945 - loss: 0.0505
# Epoch 21: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.9945 - loss: 0.0505 - val_accuracy: 0.8230 - val_loss: 0.8944 - learning_rate: 1.0000e-04
# Epoch 22/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.9955 - loss: 0.0493 - val_accuracy: 0.8201 - val_loss: 0.8022 - learning_rate: 1.0000e-05
# Epoch 23/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.9976 - loss: 0.0422 - val_accuracy: 0.8241 - val_loss: 0.8005 - learning_rate: 1.0000e-05
# Epoch 24/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9980 - loss: 0.0369 - val_accuracy: 0.8236 - val_loss: 0.7913 - learning_rate: 1.0000e-05
# Epoch 25/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.9986 - loss: 0.0332 - val_accuracy: 0.8253 - val_loss: 0.8131 - learning_rate: 1.0000e-05
# Epoch 26/30
# 428/431 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9975 - loss: 0.0383
# Epoch 26: ReduceLROnPlateau reducing learning rate to 1e-05.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.9975 - loss: 0.0383 - val_accuracy: 0.8241 - val_loss: 0.7746 - learning_rate: 1.0000e-05
# Epoch 26: early stopping
# Restoring model weights from the end of the best epoch: 16.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 73ms/step
# Precisão : 0.7892472969104124
# Recall : 0.843049588952577
# F1-Score : 0.8096684829946028
# OIBOMDIA 5
# Epoch 1/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 43s 56ms/step - accuracy: 0.7210 - loss: 8.9668 - val_accuracy: 0.8056 - val_loss: 2.1726 - learning_rate: 0.0010
# Epoch 2/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.7856 - loss: 1.6612 - val_accuracy: 0.7934 - val_loss: 0.8585 - learning_rate: 0.0010
# Epoch 3/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.8184 - loss: 0.6547 - val_accuracy: 0.8085 - val_loss: 0.5248 - learning_rate: 0.0010
# Epoch 4/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.8450 - loss: 0.4431 - val_accuracy: 0.8201 - val_loss: 0.4933 - learning_rate: 0.0010
# Epoch 5/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8649 - loss: 0.3911 - val_accuracy: 0.8102 - val_loss: 0.5575 - learning_rate: 0.0010
# Epoch 6/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.8923 - loss: 0.3380 - val_accuracy: 0.7992 - val_loss: 0.5199 - learning_rate: 0.0010
# Epoch 7/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.9010 - loss: 0.3179 - val_accuracy: 0.8247 - val_loss: 0.5113 - learning_rate: 0.0010
# Epoch 8/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.9184 - loss: 0.3102 - val_accuracy: 0.7847 - val_loss: 0.6686 - learning_rate: 0.0010
# Epoch 9/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9270 - loss: 0.2849 - val_accuracy: 0.7934 - val_loss: 0.5830 - learning_rate: 0.0010
# Epoch 10/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.9409 - loss: 0.2591 - val_accuracy: 0.8259 - val_loss: 0.6958 - learning_rate: 0.0010
# Epoch 11/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9423 - loss: 0.2519 - val_accuracy: 0.8114 - val_loss: 0.5913 - learning_rate: 0.0010
# Epoch 12/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9420 - loss: 0.2504 - val_accuracy: 0.8207 - val_loss: 0.6644 - learning_rate: 0.0010
# Epoch 13/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9538 - loss: 0.2253 - val_accuracy: 0.8125 - val_loss: 0.6164 - learning_rate: 0.0010
# Epoch 14/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9576 - loss: 0.2248 - val_accuracy: 0.8096 - val_loss: 0.6672 - learning_rate: 0.0010
# Epoch 15/30
# 430/431 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9624 - loss: 0.2120
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9624 - loss: 0.2121 - val_accuracy: 0.6454 - val_loss: 1.0575 - learning_rate: 0.0010
# Epoch 16/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9781 - loss: 0.1588 - val_accuracy: 0.8195 - val_loss: 0.5497 - learning_rate: 1.0000e-04
# Epoch 17/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9865 - loss: 0.0896 - val_accuracy: 0.8085 - val_loss: 0.6680 - learning_rate: 1.0000e-04
# Epoch 18/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9907 - loss: 0.0669 - val_accuracy: 0.8131 - val_loss: 0.7327 - learning_rate: 1.0000e-04
# Epoch 19/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9905 - loss: 0.0698 - val_accuracy: 0.8195 - val_loss: 0.6729 - learning_rate: 1.0000e-04
# Epoch 20/30
# 428/431 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9936 - loss: 0.0523
# Epoch 20: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9936 - loss: 0.0523 - val_accuracy: 0.8166 - val_loss: 0.9048 - learning_rate: 1.0000e-04
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 10.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 70ms/step
# Precisão : 0.7524359457253804
# Recall : 0.8368360118228487
# F1-Score : 0.7726214018896945
# OIBOMDIA 6
# Epoch 1/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 41s 53ms/step - accuracy: 0.7071 - loss: 8.6298 - val_accuracy: 0.7824 - val_loss: 1.8396 - learning_rate: 0.0010
# Epoch 2/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7939 - loss: 1.3766 - val_accuracy: 0.8108 - val_loss: 0.7032 - learning_rate: 0.0010
# Epoch 3/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8286 - loss: 0.5725 - val_accuracy: 0.8033 - val_loss: 0.5065 - learning_rate: 0.0010
# Epoch 4/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8484 - loss: 0.4354 - val_accuracy: 0.8195 - val_loss: 0.4812 - learning_rate: 0.0010
# Epoch 5/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8686 - loss: 0.3855 - val_accuracy: 0.7922 - val_loss: 0.5763 - learning_rate: 0.0010
# Epoch 6/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9023 - loss: 0.3304 - val_accuracy: 0.7324 - val_loss: 0.7871 - learning_rate: 0.0010
# Epoch 7/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9060 - loss: 0.3232 - val_accuracy: 0.7632 - val_loss: 0.6910 - learning_rate: 0.0010
# Epoch 8/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9286 - loss: 0.2921 - val_accuracy: 0.8108 - val_loss: 0.5749 - learning_rate: 0.0010
# Epoch 9/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9357 - loss: 0.2507
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9357 - loss: 0.2507 - val_accuracy: 0.8120 - val_loss: 0.5631 - learning_rate: 0.0010
# Epoch 10/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9473 - loss: 0.2197 - val_accuracy: 0.8323 - val_loss: 0.4761 - learning_rate: 1.0000e-04
# Epoch 11/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9667 - loss: 0.1345 - val_accuracy: 0.8276 - val_loss: 0.5816 - learning_rate: 1.0000e-04
# Epoch 12/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9838 - loss: 0.0936 - val_accuracy: 0.8253 - val_loss: 0.7245 - learning_rate: 1.0000e-04
# Epoch 13/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9839 - loss: 0.0884 - val_accuracy: 0.8381 - val_loss: 0.6096 - learning_rate: 1.0000e-04
# Epoch 14/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9912 - loss: 0.0648 - val_accuracy: 0.8305 - val_loss: 0.6372 - learning_rate: 1.0000e-04
# Epoch 15/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9894 - loss: 0.0736 - val_accuracy: 0.8294 - val_loss: 0.8038 - learning_rate: 1.0000e-04
# Epoch 16/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9911 - loss: 0.0631 - val_accuracy: 0.8282 - val_loss: 0.6888 - learning_rate: 1.0000e-04
# Epoch 17/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9910 - loss: 0.0685 - val_accuracy: 0.8247 - val_loss: 0.7407 - learning_rate: 1.0000e-04
# Epoch 18/30
# 429/431 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9956 - loss: 0.0463
# Epoch 18: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9955 - loss: 0.0463 - val_accuracy: 0.8212 - val_loss: 0.8148 - learning_rate: 1.0000e-04
# Epoch 19/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9952 - loss: 0.0530 - val_accuracy: 0.8305 - val_loss: 0.7976 - learning_rate: 1.0000e-05
# Epoch 20/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9949 - loss: 0.0466 - val_accuracy: 0.8241 - val_loss: 0.8114 - learning_rate: 1.0000e-05
# Epoch 21/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9970 - loss: 0.0374 - val_accuracy: 0.8305 - val_loss: 0.7912 - learning_rate: 1.0000e-05
# Epoch 22/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9983 - loss: 0.0331 - val_accuracy: 0.8317 - val_loss: 0.8151 - learning_rate: 1.0000e-05
# Epoch 23/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9988 - loss: 0.0283
# Epoch 23: ReduceLROnPlateau reducing learning rate to 1e-05.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9988 - loss: 0.0283 - val_accuracy: 0.8276 - val_loss: 0.7493 - learning_rate: 1.0000e-05
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 13.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 69ms/step
# Precisão : 0.8075582935877054
# Recall : 0.8472438283054315
# F1-Score : 0.8242515234478496
# OIBOMDIA 7
# Epoch 1/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 41s 53ms/step - accuracy: 0.7168 - loss: 9.1713 - val_accuracy: 0.7626 - val_loss: 2.1362 - learning_rate: 0.0010
# Epoch 2/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7856 - loss: 1.5954 - val_accuracy: 0.7934 - val_loss: 0.7356 - learning_rate: 0.0010
# Epoch 3/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8409 - loss: 0.6179 - val_accuracy: 0.8114 - val_loss: 0.5199 - learning_rate: 0.0010
# Epoch 4/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8578 - loss: 0.4334 - val_accuracy: 0.7887 - val_loss: 0.6048 - learning_rate: 0.0010
# Epoch 5/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8641 - loss: 0.3993 - val_accuracy: 0.7945 - val_loss: 0.5231 - learning_rate: 0.0010
# Epoch 6/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8967 - loss: 0.3436 - val_accuracy: 0.7742 - val_loss: 0.7688 - learning_rate: 0.0010
# Epoch 7/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9040 - loss: 0.3148 - val_accuracy: 0.8033 - val_loss: 0.5655 - learning_rate: 0.0010
# Epoch 8/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9249 - loss: 0.2909
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9249 - loss: 0.2909 - val_accuracy: 0.8102 - val_loss: 0.6424 - learning_rate: 0.0010
# Epoch 9/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9377 - loss: 0.2367 - val_accuracy: 0.8172 - val_loss: 0.4942 - learning_rate: 1.0000e-04
# Epoch 10/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9659 - loss: 0.1473 - val_accuracy: 0.8323 - val_loss: 0.4854 - learning_rate: 1.0000e-04
# Epoch 11/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9762 - loss: 0.1059 - val_accuracy: 0.8265 - val_loss: 0.5213 - learning_rate: 1.0000e-04
# Epoch 12/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9789 - loss: 0.0963 - val_accuracy: 0.8288 - val_loss: 0.5309 - learning_rate: 1.0000e-04
# Epoch 13/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9829 - loss: 0.0804 - val_accuracy: 0.8207 - val_loss: 0.6823 - learning_rate: 1.0000e-04
# Epoch 14/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9828 - loss: 0.0802 - val_accuracy: 0.8236 - val_loss: 0.6302 - learning_rate: 1.0000e-04
# Epoch 15/30
# 429/431 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9861 - loss: 0.0771
# Epoch 15: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9861 - loss: 0.0771 - val_accuracy: 0.8259 - val_loss: 0.6736 - learning_rate: 1.0000e-04
# Epoch 16/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9953 - loss: 0.0534 - val_accuracy: 0.8236 - val_loss: 0.6645 - learning_rate: 1.0000e-05
# Epoch 17/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9928 - loss: 0.0561 - val_accuracy: 0.8247 - val_loss: 0.6624 - learning_rate: 1.0000e-05
# Epoch 18/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9968 - loss: 0.0411 - val_accuracy: 0.8178 - val_loss: 0.7082 - learning_rate: 1.0000e-05
# Epoch 19/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.9980 - loss: 0.0375 - val_accuracy: 0.8149 - val_loss: 0.6938 - learning_rate: 1.0000e-05
# Epoch 20/30
# 428/431 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9962 - loss: 0.0413
# Epoch 20: ReduceLROnPlateau reducing learning rate to 1e-05.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9962 - loss: 0.0413 - val_accuracy: 0.8253 - val_loss: 0.6941 - learning_rate: 1.0000e-05
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 10.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 69ms/step
# Precisão : 0.7898429343998621
# Recall : 0.8318160876901168
# F1-Score : 0.8069787468376478
# OIBOMDIA 8
# Epoch 1/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 41s 53ms/step - accuracy: 0.7183 - loss: 8.6537 - val_accuracy: 0.8131 - val_loss: 1.8461 - learning_rate: 0.0010
# Epoch 2/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7883 - loss: 1.4007 - val_accuracy: 0.7696 - val_loss: 0.7090 - learning_rate: 0.0010
# Epoch 3/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8341 - loss: 0.5674 - val_accuracy: 0.7829 - val_loss: 0.5292 - learning_rate: 0.0010
# Epoch 4/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.8510 - loss: 0.4443 - val_accuracy: 0.8160 - val_loss: 0.5266 - learning_rate: 0.0010
# Epoch 5/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8863 - loss: 0.3590 - val_accuracy: 0.8038 - val_loss: 0.5690 - learning_rate: 0.0010
# Epoch 6/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8940 - loss: 0.3373 - val_accuracy: 0.8143 - val_loss: 0.5097 - learning_rate: 0.0010
# Epoch 7/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9074 - loss: 0.3092 - val_accuracy: 0.8085 - val_loss: 0.7615 - learning_rate: 0.0010
# Epoch 8/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9202 - loss: 0.2963 - val_accuracy: 0.7945 - val_loss: 0.7195 - learning_rate: 0.0010
# Epoch 9/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9257 - loss: 0.2636 - val_accuracy: 0.8305 - val_loss: 0.4815 - learning_rate: 0.0010
# Epoch 10/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9445 - loss: 0.2422 - val_accuracy: 0.7696 - val_loss: 1.0252 - learning_rate: 0.0010
# Epoch 11/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9410 - loss: 0.2522 - val_accuracy: 0.8230 - val_loss: 0.5826 - learning_rate: 0.0010
# Epoch 12/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9542 - loss: 0.2318 - val_accuracy: 0.8253 - val_loss: 0.5808 - learning_rate: 0.0010
# Epoch 13/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9525 - loss: 0.2261 - val_accuracy: 0.7980 - val_loss: 0.6487 - learning_rate: 0.0010
# Epoch 14/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9579 - loss: 0.2209
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9579 - loss: 0.2209 - val_accuracy: 0.8265 - val_loss: 0.6336 - learning_rate: 0.0010
# Epoch 15/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9666 - loss: 0.1809 - val_accuracy: 0.8172 - val_loss: 0.5463 - learning_rate: 1.0000e-04
# Epoch 16/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9866 - loss: 0.0923 - val_accuracy: 0.8323 - val_loss: 0.5396 - learning_rate: 1.0000e-04
# Epoch 17/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9889 - loss: 0.0815 - val_accuracy: 0.8311 - val_loss: 0.6577 - learning_rate: 1.0000e-04
# Epoch 18/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9951 - loss: 0.0557 - val_accuracy: 0.8363 - val_loss: 0.6722 - learning_rate: 1.0000e-04
# Epoch 19/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9891 - loss: 0.0593 - val_accuracy: 0.8398 - val_loss: 0.6874 - learning_rate: 1.0000e-04
# Epoch 20/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9955 - loss: 0.0452 - val_accuracy: 0.8427 - val_loss: 0.7316 - learning_rate: 1.0000e-04
# Epoch 21/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9976 - loss: 0.0366 - val_accuracy: 0.8381 - val_loss: 0.7692 - learning_rate: 1.0000e-04
# Epoch 22/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9937 - loss: 0.0443 - val_accuracy: 0.8375 - val_loss: 0.6535 - learning_rate: 1.0000e-04
# Epoch 23/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9928 - loss: 0.0519 - val_accuracy: 0.8445 - val_loss: 0.5844 - learning_rate: 1.0000e-04
# Epoch 24/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9958 - loss: 0.0413 - val_accuracy: 0.8299 - val_loss: 0.8344 - learning_rate: 1.0000e-04
# Epoch 25/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9965 - loss: 0.0402 - val_accuracy: 0.8317 - val_loss: 0.7933 - learning_rate: 1.0000e-04
# Epoch 26/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9965 - loss: 0.0405 - val_accuracy: 0.8352 - val_loss: 0.5950 - learning_rate: 1.0000e-04
# Epoch 27/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9900 - loss: 0.0586 - val_accuracy: 0.8352 - val_loss: 0.6967 - learning_rate: 1.0000e-04
# Epoch 28/30
# 428/431 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9957 - loss: 0.0399
# Epoch 28: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9957 - loss: 0.0398 - val_accuracy: 0.8317 - val_loss: 0.7839 - learning_rate: 1.0000e-04
# Epoch 29/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9976 - loss: 0.0352 - val_accuracy: 0.8328 - val_loss: 0.6762 - learning_rate: 1.0000e-05
# Epoch 30/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9995 - loss: 0.0271 - val_accuracy: 0.8299 - val_loss: 0.6724 - learning_rate: 1.0000e-05
# Restoring model weights from the end of the best epoch: 23.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 68ms/step
# Precisão : 0.7840144788845496
# Recall : 0.8449372958225136
# F1-Score : 0.8058034613925853
# OIBOMDIA 9
# Epoch 1/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 41s 53ms/step - accuracy: 0.7028 - loss: 8.8814 - val_accuracy: 0.7905 - val_loss: 1.9438 - learning_rate: 0.0010
# Epoch 2/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7874 - loss: 1.4689 - val_accuracy: 0.7928 - val_loss: 0.7767 - learning_rate: 0.0010
# Epoch 3/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8337 - loss: 0.5891 - val_accuracy: 0.7980 - val_loss: 0.5492 - learning_rate: 0.0010
# Epoch 4/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8497 - loss: 0.4416 - val_accuracy: 0.8195 - val_loss: 0.5128 - learning_rate: 0.0010
# Epoch 5/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8741 - loss: 0.3623 - val_accuracy: 0.8015 - val_loss: 0.5316 - learning_rate: 0.0010
# Epoch 6/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8968 - loss: 0.3290 - val_accuracy: 0.7864 - val_loss: 0.5769 - learning_rate: 0.0010
# Epoch 7/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9090 - loss: 0.3235 - val_accuracy: 0.8108 - val_loss: 0.5891 - learning_rate: 0.0010
# Epoch 8/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9237 - loss: 0.2785 - val_accuracy: 0.7690 - val_loss: 0.8202 - learning_rate: 0.0010
# Epoch 9/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9289 - loss: 0.2690 - val_accuracy: 0.8207 - val_loss: 0.5313 - learning_rate: 0.0010
# Epoch 10/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9388 - loss: 0.2681 - val_accuracy: 0.8073 - val_loss: 0.5897 - learning_rate: 0.0010
# Epoch 11/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9525 - loss: 0.2248 - val_accuracy: 0.7998 - val_loss: 0.6899 - learning_rate: 0.0010
# Epoch 12/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9493 - loss: 0.2516 - val_accuracy: 0.8003 - val_loss: 0.5883 - learning_rate: 0.0010
# Epoch 13/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9551 - loss: 0.2229 - val_accuracy: 0.8079 - val_loss: 0.5901 - learning_rate: 0.0010
# Epoch 14/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9608 - loss: 0.2197
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9608 - loss: 0.2197 - val_accuracy: 0.8125 - val_loss: 0.6101 - learning_rate: 0.0010
# Epoch 15/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9703 - loss: 0.1837 - val_accuracy: 0.8236 - val_loss: 0.5391 - learning_rate: 1.0000e-04
# Epoch 16/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9879 - loss: 0.0890 - val_accuracy: 0.8201 - val_loss: 0.5396 - learning_rate: 1.0000e-04
# Epoch 17/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9921 - loss: 0.0659 - val_accuracy: 0.8189 - val_loss: 0.6264 - learning_rate: 1.0000e-04
# Epoch 18/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9965 - loss: 0.0405 - val_accuracy: 0.8201 - val_loss: 0.7948 - learning_rate: 1.0000e-04
# Epoch 19/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9918 - loss: 0.0527 - val_accuracy: 0.8149 - val_loss: 0.5038 - learning_rate: 1.0000e-04
# Epoch 20/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9955 - loss: 0.0444
# Epoch 20: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 9s 22ms/step - accuracy: 0.9955 - loss: 0.0444 - val_accuracy: 0.8172 - val_loss: 0.6803 - learning_rate: 1.0000e-04
# Epoch 21/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9981 - loss: 0.0362 - val_accuracy: 0.8172 - val_loss: 0.7212 - learning_rate: 1.0000e-05
# Epoch 22/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9972 - loss: 0.0357 - val_accuracy: 0.8137 - val_loss: 0.7068 - learning_rate: 1.0000e-05
# Epoch 23/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9981 - loss: 0.0353 - val_accuracy: 0.8166 - val_loss: 0.7766 - learning_rate: 1.0000e-05
# Epoch 24/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9987 - loss: 0.0300 - val_accuracy: 0.8189 - val_loss: 0.7758 - learning_rate: 1.0000e-05
# Epoch 25/30
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9994 - loss: 0.0283
# Epoch 25: ReduceLROnPlateau reducing learning rate to 1e-05.
# 431/431 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9994 - loss: 0.0283 - val_accuracy: 0.8172 - val_loss: 0.7601 - learning_rate: 1.0000e-05
# Epoch 25: early stopping
# Restoring model weights from the end of the best epoch: 15.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 69ms/step
# Precisão : 0.8009046265184803
# Recall : 0.8482834133090813
# F1-Score : 0.8199080093234168
# Acurácia média: 0.8541206030150754 ± 0.01721213729496867
# Precisão média: 0.7857717792993876 ± 0.01739310635672369
# Recall médio: 0.8427018141132265 ± 0.008719956278666325
# F1-Score médio: 0.8057522970856201 ± 0.016644932181511207

# %%
#model.save_weights('/kaggle/working/VGG-16.weights.h5')
